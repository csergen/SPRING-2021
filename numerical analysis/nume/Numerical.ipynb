# %%
import numpy as np
import pandas as pd
from sympy import *

x, y, z = symbols('x y z')

class Nume:

    @staticmethod
    def cramer(A: np.ndarray, b: np.ndarray) -> np.ndarray:
        if np.shape(A) != (len(A[0, :]), len(A[:, 0])):
            print(f"A is not a square matrix: A{ np.shape(A) }")
            return np.NaN
    
        delta_n = []
    
        for i in range(len(b)):
            copy_A = A.copy()
            copy_A[:, i] = b
        
            resval = np.linalg.det(copy_A) / np.linalg.det(A)
            delta_n.append(resval)
    
        return np.array(delta_n)

    @staticmethod
    def bisection(equ, interval: list, itr: int,
                  epsilon: float=None,
                  real_root: float=None) -> pd.DataFrame:
        err: float = None
        arr: list = []
        root: float = lambda t: float(equ.subs(x, t))
        chrt: bool = lambda a, b: ( root(a) * root(b) < 0 )
        
        while (itr > 0):
            lower, upper = interval
            if chrt(lower, upper):
                aprx = (lower + upper) / 2
                
                if chrt(lower, aprx):
                    interval[1] = aprx
                elif chrt(aprx, upper):
                    interval[0] = aprx
                
                if real_root:
                    err = np.abs(real_root - aprx)
                elif epsilon:
                    err = (upper - lower) / pow(2, counter)
                
                arr.append([lower, upper, aprx, err, epsilon])
                
                if (err and epsilon) and (err < epsilon):
                    break

                itr -= 1
            else:
                break
        
        arr = np.array(arr)
                
        df = pd.DataFrame({"lower": arr[:, 0],
                           "upper": arr[:, 1],
                           "approximate": arr[:, 2],
                           "error": arr[:, 3],
                           "epsilon": arr[:, 4]})
        df.index += 1
        
        return df
    
    @staticmethod
    def check(A: np.ndarray, x: np.ndarray, b: np.ndarray) -> bool:
        return np.allclose(np.dot(A, x), b)
    
    # Upper triangular form
    @staticmethod
    def triu(A: np.ndarray) -> np.ndarray:
        return np.triu(A)
    
    # Lower triangular form
    @staticmethod
    def tril(A: np.ndarray) -> np.ndarray:
        return np.tril(A)
    
    # Diagonal matrix form
    @staticmethod
    def diag(A: np.ndarray) -> np.ndarray:
        return np.diag(np.diag(A))
    
    @staticmethod
    def ispos(a):
        if a > 0:
            return True
        return False
    
    @staticmethod
    def isneg(a):
        if a < 0:
            return True
        return False
    
    @staticmethod
    def iszero(a):
        if a == 0:
            return True
        return False

# %%
#equ = x**3 - 7*x**2 + 14*x - 6
#equ = 4.5*x-2*cos(x)
#equ = x**3 -1*x -2
equ = x*tan(x)-3
resval = Nume.bisection(equ, [6, 7], 15)
resval
# Out:
#       lower    upper approximate error epsilon
# 1         6        7         6.5  None    None
# 2       6.5        7        6.75  None    None
# 3       6.5     6.75       6.625  None    None
# 4     6.625     6.75      6.6875  None    None
# 5    6.6875     6.75     6.71875  None    None
# 6    6.6875  6.71875     6.70312  None    None
# 7   6.70312  6.71875     6.71094  None    None
# 8   6.70312  6.71094     6.70703  None    None
# 9   6.70312  6.70703     6.70508  None    None
# 10  6.70312  6.70508      6.7041  None    None
# 11  6.70312   6.7041     6.70361  None    None
# 12  6.70361   6.7041     6.70386  None    None
# 13  6.70386   6.7041     6.70398  None    None
# 14  6.70386  6.70398     6.70392  None    None
# 15  6.70392  6.70398     6.70395  None    None

# %%
6*np.tan(6)-3
# Out:
# -4.746037148308495

# %%
def a(equ, t):
    return float(equ.subs(equ, t))

a(equ, 10)
# Out:
# 10.0
